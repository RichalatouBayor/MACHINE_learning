# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.1.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
# Using cached numpy-2.1.3-cp311-cp311-win_amd64.whl (12.9 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Richalatou/cours_machine_learning\MACHINE_learning/YNOV_DATA\challenge-housepricing-ynov/train_housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1627.0           280.0
# 4        -122.25     37.85                52.0        919.0           213.0
# ...          ...       ...                 ...          ...             ...
# 11995    -121.43     39.18                36.0       1124.0           184.0
# 11996    -121.48     39.10                19.0       2043.0           421.0
# 11997    -121.45     39.26                15.0       2319.0           416.0
# 11998    -121.53     39.19                27.0       2080.0           412.0
# 11999    -121.56     39.27                28.0       2332.0           395.0
#
# ...

# %%
import numpy as np

# %%
moyenne = df.median_house_value.mean()

# %%
moyenne
# Out:
# np.float64(206731.83833333335)

# %%
df['predicted_median_house_value'] = moyenne

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1627.0           280.0
# 4        -122.25     37.85                52.0        919.0           213.0
# ...          ...       ...                 ...          ...             ...
# 11995    -121.43     39.18                36.0       1124.0           184.0
# 11996    -121.48     39.10                19.0       2043.0           421.0
# 11997    -121.45     39.26                15.0       2319.0           416.0
# 11998    -121.53     39.19                27.0       2080.0           412.0
# 11999    -121.56     39.27                28.0       2332.0           395.0
#
# ...

# %%
# !pip install scikit-learn

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(df['predicted_median_house_value'], df['median_house_value'], squared=False)
# Out:
# C:\Users\Richalatou\AppData\Local\pypoetry\Cache\virtualenvs\ynov-gZLHl17f-py3.11\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# np.float64(115747.44174365667)

# %%
sub = pd.read_csv("C:/Users/Richalatou/cours_machine_learning\MACHINE_learning/YNOV_DATA\challenge-housepricing-ynov/submission.csv")

# %%
 sub["median_house_value"] = moyenne

# %%
sub
# Out:
#          id  median_house_value
# 0         3       206731.838333
# 1        10       206731.838333
# 2        11       206731.838333
# 3        12       206731.838333
# 4        13       206731.838333
# ...     ...                 ...
# 8635  20635       206731.838333
# 8636  20636       206731.838333
# 8637  20637       206731.838333
# 8638  20638       206731.838333
# 8639  20639       206731.838333
#
# [8640 rows x 2 columns]

# %%
sub.to_csv("C:/Users/Richalatou/cours_machine_learning\MACHINE_learning/YNOV_DATA\challenge-housepricing-ynov/submission1.csv", sep=",", index=False)
